# %% [markdown]
# # Timeseries LSTM Training
#
# Train a 3-layer LSTM (128 hidden units) on fixation sequences

# %%
from pathlib import Path

import pandas as pd

from src.dl.training import (
    DEFAULT_MAX_LENGTH,
    DEFAULT_TIMESERIES_FEATURES,
    LSTM_HIDDEN_SIZE,
    LSTM_NUM_LAYERS,
    run_training_battery,
)

DATASETS_DIR = Path("data")
SPLITS_DIR = Path("extensive_features") / "splits"
RESULTS_DIR = Path("results") / "dl"
RESULTS_FILE = RESULTS_DIR / "lstm_results.csv"

MAX_EPOCHS = 50
BATCH_SIZE = 32
TEST_MODE = False
TEST_MAX_SAMPLES = 100
SKIP_EXISTING = True

RESULTS_DIR.mkdir(parents=True, exist_ok=True)

print("Configuration:")
print(f"  datasets_dir: {DATASETS_DIR}")
print(f"  splits: {SPLITS_DIR}")
print(f"  results: {RESULTS_FILE}")
print(f"  LSTM: {LSTM_NUM_LAYERS} layers x {LSTM_HIDDEN_SIZE} units")
print(f"  sequence features: {DEFAULT_TIMESERIES_FEATURES}")
print(f"  max_length: {DEFAULT_MAX_LENGTH}")
print(f"  max_epochs: {MAX_EPOCHS}, batch_size: {BATCH_SIZE}")
print(f"  test_mode: {TEST_MODE}")
# Out:
# Configuration:
#   datasets_dir: data
#   splits: extensive_features\splits
#   results: results\dl\lstm_results.csv
#   LSTM: 3 layers x 128 units
#   sequence features: ['duration']
#   max_length: 300
#   max_epochs: 50, batch_size: 32
#   test_mode: False

# %%
results_df = run_training_battery(
    splits_dir=SPLITS_DIR,
    results_file=RESULTS_FILE,
    datasets_dir=DATASETS_DIR,
    max_epochs=MAX_EPOCHS,
    batch_size=BATCH_SIZE,
    timeseries_features=DEFAULT_TIMESERIES_FEATURES,
    max_length=DEFAULT_MAX_LENGTH,
    skip_existing=SKIP_EXISTING,
    test_mode=TEST_MODE,
    test_max_samples=TEST_MAX_SAMPLES,
)

if results_df.empty and RESULTS_FILE.exists():
    results_df = pd.read_csv(RESULTS_FILE)

print(f"\nDone. {len(results_df)} rows in {RESULTS_FILE}")
# Out:
# Found 10 datasets with splits to process
# Datasets:   0%|          | 0/10 [00:00<?, ?it/s]
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: 3D (84,093 rows, 1 split(s))
# ============================================================
#
#   Label: condition_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 1799/1799 [00:00<00:00, 5443.52it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# You are using a CUDA device ('NVIDIA GeForce RTX 4080 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\utilities\model_summary\model_summary.py:543: The total number of parameters detected may be inaccurate because the model contains an instance of `UninitializedParameter`. To get an accurate number, set `self.example_input_array` in your LightningModule.
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:37<00:00,  1.32epoch/s, epoch=49]
# acc=0.1833, f1_macro=0.1757
# Datasets:  10%|█         | 1/10 [00:40<06:06, 40.70s/it]
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: AFC (39,358 rows, 2 split(s))
# ============================================================
#
#   Label: mod_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 2554/2554 [00:00<00:00, 6953.31it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:26<00:00,  1.86epoch/s, epoch=49]
# acc=0.1680, f1_macro=0.1592
#
#   Label: scr_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 2554/2554 [00:00<00:00, 7374.56it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:26<00:00,  1.89epoch/s, epoch=49]
# acc=0.1895, f1_macro=0.1401
# Datasets:  20%|██        | 2/10 [01:37<06:39, 49.89s/it]
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: APP (99,101 rows, 3 split(s))
# ============================================================
#
#   Label: known_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 4546/4546 [00:00<00:00, 6871.42it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [02:03<00:00,  2.46s/epoch, epoch=49]
# acc=0.7489, f1_macro=0.4364
#
#   Label: meta_certainty_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 4546/4546 [00:01<00:00, 2940.31it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [02:25<00:00,  2.90s/epoch, epoch=49]
# acc=0.4117, f1_macro=0.1552
#
#   Label: mod_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 4546/4546 [00:01<00:00, 3826.66it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [02:23<00:00,  2.87s/epoch, epoch=49]
# acc=0.5553, f1_macro=0.1827
# Datasets:  30%|███       | 3/10 [08:45<26:00, 222.88s/it]
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: Age_study (105,813 rows, 1 split(s))
# ============================================================
#
#   Label: meta_age_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 7391/7391 [00:02<00:00, 2975.07it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [02:06<00:00,  2.53s/epoch, epoch=49]
# acc=0.3595, f1_macro=0.3474
# Datasets:  40%|████      | 4/10 [10:59<18:45, 187.62s/it]
# ============================================================
# Dataset: Cognitive_load_fixations_0.02 (32,797 rows, 6 split(s))
# ============================================================
#
#   Label: effort_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 188/188 [00:00<00:00, 3341.66it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:20<00:00,  2.45epoch/s, epoch=49]
# r2=-0.7544
#
#   Label: frustration_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 188/188 [00:00<00:00, 2978.91it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:21<00:00,  2.27epoch/s, epoch=49]
# r2=-0.0329
#
#   Label: mental_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 188/188 [00:00<00:00, 2486.28it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:23<00:00,  2.12epoch/s, epoch=49]
# r2=-0.7460
#
#   Label: performance_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 188/188 [00:00<00:00, 2244.92it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:24<00:00,  2.08epoch/s, epoch=49]
# r2=-0.1739
#
#   Label: physical_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 188/188 [00:00<00:00, 2651.80it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:24<00:00,  2.07epoch/s, epoch=49]
# r2=-0.0210
#
#   Label: temporal_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 188/188 [00:00<00:00, 2370.50it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:24<00:00,  2.07epoch/s, epoch=49]
# r2=-0.1680
# Datasets:  50%|█████     | 5/10 [13:26<14:25, 173.14s/it]
# ============================================================
# Dataset: Emotions_fixations_0.02 (105,395 rows, 3 split(s))
# ============================================================
#
#   Label: Disgust_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 432/432 [00:00<00:00, 2315.38it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([28])) that is different to the input size (torch.Size([28, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([26])) that is different to the input size (torch.Size([26, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:46<00:00,  1.08epoch/s, epoch=49]
# r2=-0.0045
#
#   Label: Sadness_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 432/432 [00:00<00:00, 2417.00it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([28])) that is different to the input size (torch.Size([28, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([26])) that is different to the input size (torch.Size([26, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:47<00:00,  1.06epoch/s, epoch=49]
# r2=-0.0000
#
#   Label: Tenderness_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 432/432 [00:00<00:00, 2495.03it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type           | Params | Mode  | FLOPs
# ------------------------------------------------------------
# 0 | backbone | DictWrapperRNN | 332 K  | train | 0
# 1 | head     | ModuleList     | 0      | train | 0
# 2 | loss_fn  | MSELoss        | 0      | train | 0
# 3 | flat     | Flatten        | 0      | train | 0
# ------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([28])) that is different to the input size (torch.Size([28, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning: Using a target size (torch.Size([26])) that is different to the input size (torch.Size([26, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:52<00:00,  1.05s/epoch, epoch=49]
# r2=-0.0023
# Datasets:  60%|██████    | 6/10 [16:02<11:08, 167.08s/it]
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: Gap (49,208 rows, 1 split(s))
# ============================================================
#
#   Label: gap_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 2880/2880 [00:01<00:00, 2278.31it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:58<00:00,  1.18s/epoch, epoch=49]
# acc=0.2317, f1_macro=0.2113
# Datasets:  70%|███████   | 7/10 [17:04<06:38, 132.95s/it]
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: Memory (109,830 rows, 2 split(s))
# ============================================================
#
#   Label: condition_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 6115/6115 [00:02<00:00, 2517.05it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [02:04<00:00,  2.48s/epoch, epoch=49]
# acc=0.3866, f1_macro=0.3826
# Datasets:  80%|████████  | 8/10 [19:16<04:24, 132.40s/it]
# Skipping condition_label (already in results)
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: Webtask (151,581 rows, 6 split(s))
# ============================================================
#
#   Label: familiarity_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 4361/4361 [00:01<00:00, 2590.08it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [03:45<00:00,  4.51s/epoch, epoch=49]
# acc=0.7923, f1_macro=0.1474
#
#   Label: relevance_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 4361/4361 [00:01<00:00, 2633.11it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [03:41<00:00,  4.44s/epoch, epoch=49]
# acc=0.6451, f1_macro=0.1307
#
#   Label: search_result_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 4361/4361 [00:01<00:00, 2499.62it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [03:41<00:00,  4.42s/epoch, epoch=49]
# acc=0.6121, f1_macro=0.1312
# Skipping familiarity_label (already in results)
# Skipping relevance_label (already in results)
# Skipping search_result_label (already in results)
# Datasets:  90%|█████████ | 9/10 [30:50<05:08, 308.20s/it]
# Computed duration from timestamp_start and timestamp_end
#
# ============================================================
# Dataset: Webtask_school (40,553 rows, 3 split(s))
# ============================================================
#
#   Label: familiarity_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 1247/1247 [00:00<00:00, 2607.67it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:54<00:00,  1.09s/epoch, epoch=49]
# acc=0.8962, f1_macro=0.2363
#
#   Label: relevance_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 1247/1247 [00:00<00:00, 2664.86it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [01:01<00:00,  1.24s/epoch, epoch=49]
# acc=0.6192, f1_macro=0.1499
#
#   Label: search_result_label
#     Training timeseries LSTM...
# Building sequences: 100%|██████████| 1247/1247 [00:00<00:00, 3797.61it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type             | Params | Mode  | FLOPs
# --------------------------------------------------------------
# 0 | backbone | DictWrapperRNN   | 332 K  | train | 0
# 1 | head     | ModuleList       | 0      | train | 0
# 2 | loss_fn  | CrossEntropyLoss | 0      | train | 0
# 3 | flat     | Flatten          | 0      | train | 0
# --------------------------------------------------------------
# 332 K     Trainable params
# 0         Non-trainable params
# 332 K     Total params
# 1.329     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# c:\Users\LEGION\miniconda3\envs\eyefeatures\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch: 100%|██████████| 50/50 [00:49<00:00,  1.01epoch/s, epoch=49]
# acc=0.6462, f1_macro=0.1308
# Datasets: 100%|██████████| 10/10 [33:44<00:00, 202.41s/it]
# Saved 24 results to results\dl\lstm_results.csv
#
# Done. 24 rows in results\dl\lstm_results.csv
